# %% [markdown]
# # Project 3, Part 3 - MySQL Database
# * Jacob Wang
# * 1/11/2023
# * Coding Dojo Data Science Project 3

# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import pymysql
from sqlalchemy import create_engine
from sqlalchemy_utils import create_database, database_exists
pymysql.install_as_MySQLdb()

# %%
basics = pd.read_csv('Data/title_basics.csv.gz')
basics.info()
basics.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80219 entries, 0 to 80218
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          80219 non-null  object
#  1   titleType       80219 non-null  object
#  2   primaryTitle    80219 non-null  object
#  3   originalTitle   80219 non-null  object
#  4   isAdult         80219 non-null  int64
#  5   startYear       80219 non-null  int64
#  6   endYear         0 non-null      float64
#  7   runtimeMinutes  80219 non-null  int64
#  8   genres          80219 non-null  object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 5.5+ MB
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                       Crime and Punishment        0       2002      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4             126                   Drama

# %%
## create a col with a list of genres
basics['genres_split'] = basics['genres'].str.split(',')
basics
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# 3      tt0088751     movie                                  The Naked Monster
# 4      tt0096056     movie                               Crime and Punishment
# ...          ...       ...                                                ...
# 80214  tt9914942     movie                             Life Without Sara Amat
# 80215  tt9915872     movie                               The Last White Witch
# 80216  tt9916170     movie                                      The Rehearsal
# 80217  tt9916190     movie                                          Safeguard
# 80218  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0       2001      NaN
# 1      El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                     The Other Side of the Wind        0       2018      NaN
# 3                              The Naked Monster        0       2005      NaN
# 4                           Crime and Punishment        0       2002      NaN
# ...                                          ...      ...        ...      ...
# 80214                 La vida sense la Sara Amat        0       2019      NaN
# 80215                  My Girlfriend is a Wizard        0       2019      NaN
# 80216                                   O Ensaio        0       2019      NaN
# 80217                                  Safeguard        0       2020      NaN
# 80218                                   Akelarre        0       2020      NaN
#
#        runtimeMinutes                     genres  \
# 0                 118     Comedy,Fantasy,Romance
# 1                  70                      Drama
# 2                 122                      Drama
# 3                 100       Comedy,Horror,Sci-Fi
# 4                 126                      Drama
# ...               ...                        ...
# 80214              74                      Drama
# 80215              97       Comedy,Drama,Fantasy
# 80216              51                      Drama
# 80217              95  Action,Adventure,Thriller
# 80218              92              Drama,History
#
#                         genres_split
# 0         [Comedy, Fantasy, Romance]
# 1                            [Drama]
# 2                            [Drama]
# 3           [Comedy, Horror, Sci-Fi]
# 4                            [Drama]
# ...                              ...
# 80214                        [Drama]
# 80215       [Comedy, Drama, Fantasy]
# 80216                        [Drama]
# 80217  [Action, Adventure, Thriller]
# 80218               [Drama, History]
#
# [80219 rows x 10 columns]

# %%
# separate the list of genres into new rows
exploded_genres = basics.explode('genres_split')
exploded_genres
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049     movie                         The Other Side of the Wind
# ...          ...       ...                                                ...
# 80217  tt9916190     movie                                          Safeguard
# 80217  tt9916190     movie                                          Safeguard
# 80217  tt9916190     movie                                          Safeguard
# 80218  tt9916362     movie                                              Coven
# 80218  tt9916362     movie                                              Coven
#
#                                    originalTitle  isAdult  startYear  endYear  \
# 0                                 Kate & Leopold        0       2001      NaN
# 0                                 Kate & Leopold        0       2001      NaN
# 0                                 Kate & Leopold        0       2001      NaN
# 1      El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                     The Other Side of the Wind        0       2018      NaN
# ...                                          ...      ...        ...      ...
# 80217                                  Safeguard        0       2020      NaN
# 80217                                  Safeguard        0       2020      NaN
# 80217                                  Safeguard        0       2020      NaN
# 80218                                   Akelarre        0       2020      NaN
# 80218                                   Akelarre        0       2020      NaN
#
#        runtimeMinutes                     genres genres_split
# 0                 118     Comedy,Fantasy,Romance       Comedy
# 0                 118     Comedy,Fantasy,Romance      Fantasy
# 0                 118     Comedy,Fantasy,Romance      Romance
# 1                  70                      Drama        Drama
# 2                 122                      Drama        Drama
# ...               ...                        ...          ...
# 80217              95  Action,Adventure,Thriller       Action
# 80217              95  Action,Adventure,Thriller    Adventure
# 80217              95  Action,Adventure,Thriller     Thriller
# 80218              92              Drama,History        Drama
# 80218              92              Drama,History      History
#
# [150248 rows x 10 columns]

# %%
# get unique genres
unique_genres = sorted(exploded_genres['genres_split'].unique())

# %% [markdown]
# ## Create title_genres table

# %%
title_genres = exploded_genres[['tconst', 'genres_split']].copy()
title_genres.head()
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 0  tt0035423      Fantasy
# 0  tt0035423      Romance
# 1  tt0062336        Drama
# 2  tt0069049        Drama

# %% [markdown]
# ## Create a genre mapper dictionary to replace string genres with integers

# %%
## Making the genre mapper dictionary
genre_ints = range(len(unique_genres))
genre_map = dict(zip(unique_genres, genre_ints))
genre_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Short': 20,
#  'Sport': 21,
#  'Talk-Show': 22,
#  'Thriller': 23,
#  'War': 24,
#  'Western': 25}

# %%
## Make dictionary with list of unique genres as key, new int id as values
genre_id_map = dict(zip(unique_genres, range(len(unique_genres))))
genre_id_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Short': 20,
#  'Sport': 21,
#  'Talk-Show': 22,
#  'Thriller': 23,
#  'War': 24,
#  'Western': 25}

# %% [markdown]
# ## Replace the string genres in title_genres with the new integer ids

# %%
## make new integer genre_id and drop string genres
title_genres['genre_id'] = title_genres['genres_split'].map(genre_map)
title_genres = title_genres.drop(columns = 'genres_split')
title_genres.head()
# Out:
#       tconst  genre_id
# 0  tt0035423         5
# 0  tt0035423         9
# 0  tt0035423        18
# 1  tt0062336         7
# 2  tt0069049         7

# %% [markdown]
# ## Convert the genre map dictionary into a dataframe

# %%
# manually make df with named cols from .keys and .values
genre_lookup = pd.DataFrame({'genre_name': genre_map.keys(),
                            'genre_id': genre_map.values()})
genre_lookup.head()
# Out:
#   genre_name  genre_id
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %% [markdown]
# # Save MySQL tables with tconst as the primary key

# %%
basics.dtypes
# Out:
# tconst             object
# titleType          object
# primaryTitle       object
# originalTitle      object
# isAdult             int64
# startYear           int64
# endYear           float64
# runtimeMinutes      int64
# genres             object
# genres_split       object
# dtype: object

# %%
## create connection
with open('/Users/jacobwang/.secret/mysql.json') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['username', 'password'])

# %%
connection = f"mysql+pymysql://{login['username']}:{login['password']}@localhost/movies"
engine = create_engine(connection)

# %%
# Check if the database exists. If not, create it.
if database_exists(connection) == False:
  create_database(connection)
else:
  print('The database already exists')
# Out:
# The database already exists

# %%
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0       2001      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0       2020      NaN
# 2                 The Other Side of the Wind        0       2018      NaN
# 3                          The Naked Monster        0       2005      NaN
# 4                       Crime and Punishment        0       2002      NaN
#
#    runtimeMinutes                  genres                genres_split
# 0             118  Comedy,Fantasy,Romance  [Comedy, Fantasy, Romance]
# 1              70                   Drama                     [Drama]
# 2             122                   Drama                     [Drama]
# 3             100    Comedy,Horror,Sci-Fi    [Comedy, Horror, Sci-Fi]
# 4             126                   Drama                     [Drama]

# %%
basics = basics.drop(columns = ['originalTitle', 'isAdult', 'titleType', 'genres','genres_split'])

# %%
## Example
from sqlalchemy.types import *
## Calculate max string lengths for object columns
key_len = basics['tconst'].fillna('').map(len).max()
title_len = basics['primaryTitle'].fillna('').map(len).max()
## Create a schema dictonary using Sqlalchemy datatype objects
df_schema = {
    "tconst": String(key_len+1), 
    "primaryTitle": Text(title_len+1),
    'startYear':Float(),
    'endYear':Float(),
    'runtimeMinutes':Integer()}

# %%
# Save to sql with dtype and index=False
basics.to_sql('title_basics',engine,dtype=df_schema,if_exists='replace',index=False)
# Out:
# 80219

# %%
engine.execute('ALTER TABLE title_basics ADD PRIMARY KEY (`tconst`);')

# %%
title_genres.to_sql('title_genres',engine, if_exists='replace',index=False)
# Out:
# 150248

# %%
genre_lookup.to_sql('genre_lookup',engine, if_exists='replace',index=False)
# Out:
# 26

# %%
engine.execute('ALTER TABLE genre_lookup ADD PRIMARY KEY (`genre_id`);')

# %%
# run queries to test database
q = """
SELECT * FROM title_basics
LIMIT 5;"""
pd.read_sql(q, engine)
# Out:
#       tconst                                       primaryTitle  startYear  \
# 0  tt0035423                                     Kate & Leopold     2001.0
# 1  tt0062336  The Tango of the Widower and Its Distorting Mi...     2020.0
# 2  tt0069049                         The Other Side of the Wind     2018.0
# 3  tt0088751                                  The Naked Monster     2005.0
# 4  tt0096056                               Crime and Punishment     2002.0
#
#   endYear  runtimeMinutes
# 0    None             118
# 1    None              70
# 2    None             122
# 3    None             100
# 4    None             126

# %%
# run queries to test database
q = """
SELECT * FROM title_genres
LIMIT 5;"""
pd.read_sql(q, engine)
# Out:
#       tconst  genre_id
# 0  tt0035423         5
# 1  tt0035423         9
# 2  tt0035423        18
# 3  tt0062336         7
# 4  tt0069049         7

# %%
q = """
SELECT * FROM genre_lookup
LIMIT 5;"""
pd.read_sql(q, engine)
# Out:
#   genre_name  genre_id
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %% [markdown]
# ## Create 'ratings' table

# %%
ratings = pd.read_csv('Data/title_ratings.csv.gz')

# %%
ratings.info()
ratings.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 482771 entries, 0 to 482770
# Data columns (total 3 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tconst         482771 non-null  object
#  1   averageRating  482771 non-null  float64
#  2   numVotes       482771 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 11.0+ MB
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1931
# 1  tt0000002            5.8       261
# 2  tt0000005            6.2      2563
# 3  tt0000006            5.1       176
# 4  tt0000007            5.4       805

# %%
key_len = ratings['tconst'].fillna('').map(len).max()
# create schema for ratings
ratings_schema = {
    "tconst": String(key_len+1), 
    'averageRating':Float(),
    'numVotes':Integer()}

# %%
ratings.to_sql('title_ratings',engine,dtype=ratings_schema,if_exists='replace',index=False)
# Out:
# 482771

# %%
engine.execute('ALTER TABLE title_ratings ADD PRIMARY KEY (`tconst`);')

# %%
q = """
SELECT * FROM title_ratings 
LIMIT 5; """
pd.read_sql(q, engine)
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1931
# 1  tt0000002            5.8       261
# 2  tt0000005            6.2      2563
# 3  tt0000006            5.1       176
# 4  tt0000007            5.4       805

# %% [markdown]
# ## Create tables for tmdb data

# %%
tmdb2000 = pd.read_csv('Data/final_tmdb_data_2000.csv.gz')
tmdb2001 = pd.read_csv('Data/final_tmdb_data_2001.csv.gz')
tmdb_data = pd.concat([tmdb2000, tmdb2001], axis=0)

tmdb_data.info() 
tmdb_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4472 entries, 0 to 2268
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                4472 non-null   object
#  1   adult                  4470 non-null   float64
#  2   backdrop_path          1968 non-null   object
#  3   belongs_to_collection  248 non-null    object
#  4   budget                 4470 non-null   float64
#  5   genres                 4470 non-null   object
#  6   homepage               231 non-null    object
#  7   id                     4470 non-null   float64
#  8   original_language      4470 non-null   object
#  9   original_title         4470 non-null   object
#  10  overview               4096 non-null   object
#  11  popularity             4470 non-null   float64
#  12  poster_path            3802 non-null   object
#  13  production_companies   4470 non-null   object
#  14  production_countries   4470 non-null   object
#  15  release_date           4434 non-null   object
#  16  revenue                4470 non-null   float64
#  17  runtime                4470 non-null   float64
#  18  spoken_languages       4470 non-null   object
#  19  status                 4470 non-null   object
#  20  tagline                1255 non-null   object
#  21  title                  4470 non-null   object
#  22  video                  4470 non-null   float64
#  23  vote_average           4470 non-null   float64
#  24  vote_count             4470 non-null   float64
#  25  certification          821 non-null    object
# dtypes: float64(9), object(17)
# memory usage: 943.3+ KB
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0116748    0.0  /wr0hTHwkYIRC82MwNbhOvqrw27N.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
#          id original_language   original_title  ... revenue  runtime  \
# 0       NaN               NaN              NaN  ...     NaN      NaN
# 1   62127.0                en  The Fantasticks  ...     0.0     86.0
# 2  110977.0                en    For the Cause  ...     0.0    100.0
# 3  442869.0                hi             Gang  ...     0.0    152.0
# 4  579396.0                hi         Karobaar  ...     0.0    180.0
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
#
#                                          tagline            title  video  \
# 0                                            NaN              NaN    NaN
# 1  Try to remember the first time magic happened  The Fantasticks    0.0
# 2   The ultimate showdown on a forbidden planet.    For the Cause    0.0
# 3                                            NaN             Gang    0.0
# 4                           The Business of Love         Karobaar    0.0
#
#    vote_average vote_count certification
# 0           NaN        NaN           NaN
# 1           5.5       22.0           NaN
# 2           5.1        8.0           NaN
# 3           4.0        1.0           NaN
# 4           5.5        2.0           NaN
#
# [5 rows x 26 columns]

# %%
# drop unnecessary columns
tmdb_data = tmdb_data[['imdb_id', 'budget', 'revenue', 'certification']]
tmdb_data
# Out:
#         imdb_id      budget  revenue certification
# 0             0         NaN      NaN           NaN
# 1     tt0113026  10000000.0      0.0           NaN
# 2     tt0113092         0.0      0.0           NaN
# 3     tt0116391         0.0      0.0           NaN
# 4     tt0116748         0.0      0.0           NaN
# ...         ...         ...      ...           ...
# 2264  tt7571842         0.0      0.0           NaN
# 2265  tt8929248         0.0      0.0           NaN
# 2266  tt8942962         0.0      0.0           NaN
# 2267  tt9099724         0.0      0.0           NaN
# 2268  tt9798698         0.0      0.0           NaN
#
# [4472 rows x 4 columns]

# %%
## Calculate max string lengths for object columns
key_len = tmdb_data['imdb_id'].str.len().max()
cert_len = tmdb_data['certification'].str.len().max()
## Create a schema dictonary using Sqlalchemy datatype objects
tmdb_schema = {"imdb_id": String(key_len+1), 
    "certification": Text(cert_len+1),
    'budget':Float(),
    'revenue':Float()}

# %%
tmdb_data.to_sql('tmdb_data',engine, dtype=tmdb_schema, if_exists='replace',index=False)
# Out:
# 4472

# %%
engine.execute('ALTER TABLE tmdb_data ADD PRIMARY KEY (`imdb_id`);')
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.9/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pymysql/cursors.py:148, in Cursor.execute(self, query, args)
#     146 query = self.mogrify(query, args)
# --> 148 result = self._query(query)
#     149 self._executed = query
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pymysql/cursors.py:310, in Cursor._query(self, q)
#     309 self._clear_result()
# --> 310 conn.query(q)
#     311 self._do_get_result()
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pymysql/connections.py:548, in Connection.query(self, sql, unbuffered)
#     547 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549 return self._affected_rows
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pymysql/connections.py:775, in Connection._read_query_result(self, unbuffered)
#     774     result = MySQLResult(self)
# --> 775     result.read()
#     776 self._result = result
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pymysql/connections.py:1156, in MySQLResult.read(self)
#    1155 try:
# -> 1156     first_packet = self.connection._read_packet()
#    1158     if first_packet.is_ok_packet():
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pymysql/connections.py:725, in Connection._read_packet(self, packet_type)
#     724         self._result.unbuffered_active = False
# --> 725     packet.raise_for_error()
#     726 return packet
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pymysql/protocol.py:221, in MysqlPacket.raise_for_error(self)
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pymysql/err.py:143, in raise_mysql_exception(data)
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# IntegrityError: (1062, "Duplicate entry '0' for key 'tmdb_data.PRIMARY'")
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In [37], line 1
# ----> 1 engine.execute('ALTER TABLE tmdb_data ADD PRIMARY KEY (`imdb_id`);')
#
# File <string>:2, in execute(self, statement, *multiparams, **params)
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.9/site-packages/sqlalchemy/util/deprecations.py:402, in _decorate_with_warning.<locals>.warned(fn, *args, **kwargs)
#     400 if not skip_warning:
#     401     _warn_with_version(message, version, wtype, stacklevel=3)
# --> 402 return fn(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3176, in Engine.execute(self, statement, *multiparams, **params)
#    3158 """Executes the given construct and returns a
#    3159 :class:`_engine.CursorResult`.
#    3160
#    (...)
#    3173
#    3174 """
#    3175 connection = self.connect(close_with_result=True)
# -> 3176 return connection.execute(statement, *multiparams, **params)
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1291, in Connection.execute(self, statement, *multiparams, **params)
#    1282 if isinstance(statement, util.string_types):
#    1283     util.warn_deprecated_20(
#    1284         "Passing a string to Connection.execute() is "
#    1285         "deprecated and will be removed in version 2.0.  Use the "
#    (...)
#    1288         "driver-level SQL string."
#    1289     )
# -> 1291     return self._exec_driver_sql(
#    1292         statement,
#    1293         multiparams,
#    1294         params,
#    1295         _EMPTY_EXECUTION_OPTS,
#    1296         future=False,
#    1297     )
#    1299 try:
#    1300     meth = statement._execute_on_connection
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1595, in Connection._exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1585         (
#    1586             statement,
#    1587             distilled_params,
#    (...)
#    1591             statement, distilled_parameters, execution_options
#    1592         )
#    1594 dialect = self.dialect
# -> 1595 ret = self._execute_context(
#    1596     dialect,
#    1597     dialect.execution_ctx_cls._init_statement,
#    1598     statement,
#    1599     distilled_parameters,
#    1600     execution_options,
#    1601     statement,
#    1602     distilled_parameters,
#    1603 )
#    1605 if not future:
#    1606     if self._has_events or self.engine._has_events:
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1862, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1859             branched.close()
#    1861 except BaseException as e:
# -> 1862     self._handle_dbapi_exception(
#    1863         e, statement, parameters, cursor, context
#    1864     )
#    1866 return result
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.9/site-packages/sqlalchemy/engine/base.py:2043, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2041     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2042 elif should_wrap:
# -> 2043     util.raise_(
#    2044         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2045     )
#    2046 else:
#    2047     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.9/site-packages/sqlalchemy/util/compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1817                 break
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#    1824     self.dispatch.after_cursor_execute(
#    1825         self,
#    1826         cursor,
#    (...)
#    1830         context.executemany,
#    1831     )
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.9/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pymysql/cursors.py:148, in Cursor.execute(self, query, args)
#     144     pass
#     146 query = self.mogrify(query, args)
# --> 148 result = self._query(query)
#     149 self._executed = query
#     150 return result
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pymysql/cursors.py:310, in Cursor._query(self, q)
#     308 self._last_executed = q
#     309 self._clear_result()
# --> 310 conn.query(q)
#     311 self._do_get_result()
#     312 return self.rowcount
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pymysql/connections.py:548, in Connection.query(self, sql, unbuffered)
#     546     sql = sql.encode(self.encoding, "surrogateescape")
#     547 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549 return self._affected_rows
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pymysql/connections.py:775, in Connection._read_query_result(self, unbuffered)
#     773 else:
#     774     result = MySQLResult(self)
# --> 775     result.read()
#     776 self._result = result
#     777 if result.server_status is not None:
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pymysql/connections.py:1156, in MySQLResult.read(self)
#    1154 def read(self):
#    1155     try:
# -> 1156         first_packet = self.connection._read_packet()
#    1158         if first_packet.is_ok_packet():
#    1159             self._read_ok_packet(first_packet)
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pymysql/connections.py:725, in Connection._read_packet(self, packet_type)
#     723     if self._result is not None and self._result.unbuffered_active is True:
#     724         self._result.unbuffered_active = False
# --> 725     packet.raise_for_error()
#     726 return packet
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pymysql/protocol.py:221, in MysqlPacket.raise_for_error(self)
#     219 if DEBUG:
#     220     print("errno =", errno)
# --> 221 err.raise_mysql_exception(self._data)
#
# File ~/opt/anaconda3/envs/dojo-env/lib/python3.9/site-packages/pymysql/err.py:143, in raise_mysql_exception(data)
#     141 if errorclass is None:
#     142     errorclass = InternalError if errno < 1000 else OperationalError
# --> 143 raise errorclass(errno, errval)
#
# IntegrityError: (pymysql.err.IntegrityError) (1062, "Duplicate entry '0' for key 'tmdb_data.PRIMARY'")
# [SQL: ALTER TABLE tmdb_data ADD PRIMARY KEY (`imdb_id`);]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)

# %%
q = """
SELECT * FROM tmdb_data
LIMIT 5;"""
pd.read_sql(q, engine)

# %% [markdown]
# ## Confirm all tables have been created

# %%
q = """SHOW TABLES"""
pd.read_sql(q, engine)
